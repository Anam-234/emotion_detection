# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
# Define directory paths
TRAIN_DIR = 'images/train'
TEST_DIR = 'images/test'

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir, label)):
            image_paths.append(os.path.join(dir, label, imagename))  # 🧠 Fixed typo: image.paths → image_paths
            labels.append(label)
        print(label, "completed")
    return image_paths, labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(train)
# Out:
#                                 image     label
# 0            images/train\angry\0.jpg     angry
# 1            images/train\angry\1.jpg     angry
# 2           images/train\angry\10.jpg     angry
# 3        images/train\angry\10002.jpg     angry
# 4        images/train\angry\10016.jpg     angry
# ...                               ...       ...
# 28816  images/train\surprise\9969.jpg  surprise
# 28817  images/train\surprise\9985.jpg  surprise
# 28818  images/train\surprise\9990.jpg  surprise
# 28819  images/train\surprise\9992.jpg  surprise
# 28820  images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(test)
# Out:
#                               image     label
# 0       images/test\angry\10052.jpg     angry
# 1       images/test\angry\10065.jpg     angry
# 2       images/test\angry\10079.jpg     angry
# 3       images/test\angry\10095.jpg     angry
# 4       images/test\angry\10121.jpg     angry
# ...                             ...       ...
# 7061  images/test\surprise\9806.jpg  surprise
# 7062  images/test\surprise\9830.jpg  surprise
# 7063  images/test\surprise\9853.jpg  surprise
# 7064  images/test\surprise\9878.jpg  surprise
# 7065   images/test\surprise\993.jpg  surprise
#
# [7066 rows x 2 columns]

# %%
from tqdm.notebook import tqdm

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image,color_mode='grayscale')  # 🔥 FIXED THIS LINE
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features), 48, 48, 1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]

# %%
test_features = extract_features(test['image'])
# Out:
#   0%|          | 0/7066 [00:00<?, ?it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
# Initialize the encoder
le = LabelEncoder()

# Fit it on the training labels
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
# Transform string labels to integer-encoded labels
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
# One-hot encode the labels for the model
y_train = to_categorical(y_train, num_classes=7)
y_test = to_categorical(y_test, num_classes=7)

# %%
model = Sequential()
# convolutional Layers
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
# fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
# output Layer
model.add(Dense(7, activation='softmax'))
# Out:
# C:\Users\SEI-LP95\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    'best_emotion_model.keras',  # 🔥🔥🔥
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=128,
    epochs=100,
    validation_data=(x_test, y_test),
    callbacks=[early_stop, checkpoint]
)
# Out:
# Epoch 1/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2343 - loss: 1.8403
# Epoch 1: val_accuracy improved from -inf to 0.25828, saving model to best_emotion_model.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 319s 1s/step - accuracy: 0.2343 - loss: 1.8402 - val_accuracy: 0.2583 - val_loss: 1.8123
# Epoch 2/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2511 - loss: 1.7989
# Epoch 2: val_accuracy improved from 0.25828 to 0.30017, saving model to best_emotion_model.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 334s 1s/step - accuracy: 0.2511 - loss: 1.7988 - val_accuracy: 0.3002 - val_loss: 1.7017
# Epoch 3/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3066 - loss: 1.7085
# Epoch 3: val_accuracy improved from 0.30017 to 0.41862, saving model to best_emotion_model.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 321s 1s/step - accuracy: 0.3067 - loss: 1.7084 - val_accuracy: 0.4186 - val_loss: 1.5267
# Epoch 4/100
# ...

# %%
from keras.models import load_model

model = load_model('best_emotion_model.keras')

# %%
# Emotion labels corresponding to class indices
label = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
from keras.utils import load_img, img_to_array
import numpy as np

def ef(image):
    img = load_img(image, color_mode='grayscale', target_size=(48, 48))
    feature = img_to_array(img)
    feature = feature.reshape(1, 48, 48, 1)
    return feature / 255.0

# %%
image = 'images/train/angry/27.jpg'
print("Original image is of angry")

img = ef(image)

pred = model.predict(img)
pred_label = label[pred.argmax()]

print("Model prediction is", pred_label)
# Out:
# Original image is of angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Model prediction is angry

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Input image path
image_path = 'images/train/sad/19.jpg'
print("Original image is of sad 😢")

# Preprocess
img_processed = ef(image_path)

# Predict
pred = model.predict(img_processed)
pred_label = label[np.argmax(pred)]

# Output prediction
print("Model prediction is", pred_label)

# Show the preprocessed grayscale image
plt.imshow(img_processed.squeeze(), cmap='gray')  # squeeze to remove (1, 48, 48, 1) to (48, 48)
plt.axis('off')
plt.title("Preprocessed Grayscale Image")
plt.show()
# Out:
# Original image is of sad 😢
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction is sad

# %%
# Input image path
image_path = 'images/train/fear/33.jpg'  # Replace with the actual fear image path
print("Original image is of fear 😨")

# Preprocess the image
img_processed = ef(image_path)

# Predict using the model
pred = model.predict(img_processed)
pred_label = label[np.argmax(pred)]

# Output the model's prediction
print("Model prediction is", pred_label)

# Show the image
plt.imshow(img_processed.squeeze(), cmap='gray')
plt.axis('off')
plt.title("Preprocessed Grayscale Image")
plt.show()
# Out:
# Original image is of fear 😨
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Model prediction is neutral

# %%
# Input image path
image_path = 'images/train/happy/7.jpg'  # Replace with actual happy image path
print("Original image is of happy 😊")

# Preprocess image
img_processed = ef(image_path)

# Predict
pred = model.predict(img_processed)
pred_label = label[np.argmax(pred)]

# Output
print("Model prediction is", pred_label)

# Show image
plt.imshow(img_processed.squeeze(), cmap='gray')
plt.axis('off')
plt.title("Preprocessed Grayscale Image")
plt.show()
# Out:
# Original image is of happy 😊
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Model prediction is happy

# %%
# Input image path
image_path = 'images/train/surprise/26.jpg'  # Replace with actual surprised image path
print("Original image is of surprise 😲")

# Preprocess image
img_processed = ef(image_path)

# Predict
pred = model.predict(img_processed)
pred_label = label[np.argmax(pred)]

# Output
print("Model prediction is", pred_label)

# Show image
plt.imshow(img_processed.squeeze(), cmap='gray')
plt.axis('off')
plt.title("Preprocessed Grayscale Image")
plt.show()
# Out:
# Original image is of surprise 😲
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Model prediction is surprise

# %%
# Input image path
image_path = 'images/train/disgust/299.jpg'  # Replace with actual disgust image path
print("Original image is of disgust 🤢")

# Preprocess image
img_processed = ef(image_path)

# Predict
pred = model.predict(img_processed)
pred_label = label[np.argmax(pred)]

# Output
print("Model prediction is", pred_label)

# Show image
plt.imshow(img_processed.squeeze(), cmap='gray')
plt.axis('off')
plt.title("Preprocessed Grayscale Image")
plt.show()
# Out:
# Original image is of disgust 🤢
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Model prediction is disgust
